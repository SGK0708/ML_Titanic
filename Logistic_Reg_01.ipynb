# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
## 1. Collecting the data

# %%
titanic_data=pd.read_csv("https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv")
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
## 2. Analyzing the data

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Survived', data = titanic_data, palette='Set1')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set default Seaborn style (no gridlines, no need for extra border customization)
sns.set_style("white")  # Removes gridlines but keeps borders visible

# Plot
plt.figure(figsize=(15, 6))
sns.countplot(x='Survived', data=titanic_data, palette='Set1')  # Adds distinct bar colors
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Survived', hue='Sex', data = titanic_data, palette='Set1')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the default color palette for all plots
sns.set_palette('Set1')

# Plot with 'hue' variable, using dynamic palette
plt.figure(figsize=(15, 6))
sns.countplot(x='Survived', hue='Pclass', data=titanic_data, palette=sns.color_palette("Set1", n_colors=titanic_data['Pclass'].nunique()))
plt.show()

# %%
titanic_data["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_data["Fare"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='SibSp', data=titanic_data, palette='Set1')  # Using a predefined palette with 6 different colors
plt.show()

# %%
## 3. Data Wrangling - Removing unwanted columns and missing value treatment

# %%
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(titanic_data.isnull() , yticklabels = False)
# Out:
# <Axes: >

# %%
sns.boxplot(x="Pclass", y="Age", data=titanic_data,  palette='Set1', flierprops={'marker': 'D', 'color': 'orange', 'markerfacecolor': 'green', 'markersize': 8})  # Directly defining flierprops)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.drop("Cabin", axis=1, inplace=True)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.dropna(inplace=True)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(titanic_data.isnull() , yticklabels = False, cbar=False)
# Out:
# <Axes: >

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked
# 0      0  A/5 21171   7.2500        S
# 1      0   PC 17599  71.2833        C

# %%
titanic_data.describe(include=object)
# Out:
#                            Name   Sex  Ticket Embarked
# count                       712   712     712      712
# unique                      712     2     541        3
# top     Braund, Mr. Owen Harris  male  347082        S
# freq                          1   453       7      554

# %%
pd.get_dummies(titanic_data["Sex"]).astype(int)
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 885       1     0
# 886       0     1
# 887       1     0
# 889       0     1
# 890       0     1
#
# [712 rows x 2 columns]

# %%
sex=pd.get_dummies(titanic_data["Sex"], drop_first=True).astype(int)
sex.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark=pd.get_dummies(titanic_data["Embarked"], drop_first=True).astype(int)
embark.head(5)
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
titanic_data['Embarked'].value_counts()
# Out:
# Embarked
# S    554
# C    130
# Q     28
# Name: count, dtype: int64

# %%
pcl=pd.get_dummies(titanic_data["Pclass"], drop_first=True).astype(int)
pcl.head(5)
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
titanic_data = pd.concat([titanic_data,sex, embark,pcl],axis=1)

# %%
titanic_data.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Embarked  male  Q  S  2  3
# 0      0         A/5 21171   7.2500        S     1  0  1  0  1
# 1      0          PC 17599  71.2833        C     0  0  0  0  0
# 2      0  STON/O2. 3101282   7.9250        S     0  0  1  0  1
# 3      0            113803  53.1000        S     0  0  1  0  0

# %%
titanic_data.drop(["PassengerId","Name","Sex","Ticket","Embarked","Pclass"], axis=1, inplace=True)

# %%
titanic_data
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0           0  22.0      1      0   7.2500     1  0  1  0  1
# 1           1  38.0      1      0  71.2833     0  0  0  0  0
# 2           1  26.0      0      0   7.9250     0  0  1  0  1
# 3           1  35.0      1      0  53.1000     0  0  1  0  0
# 4           0  35.0      0      0   8.0500     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 885         0  39.0      0      5  29.1250     0  1  0  0  1
# 886         0  27.0      0      0  13.0000     1  0  1  1  0
# 887         1  19.0      0      0  30.0000     0  0  1  0  0
# 889         1  26.0      0      0  30.0000     1  0  0  0  0
# 890         0  32.0      0      0   7.7500     1  1  0  0  1
#
# [712 rows x 10 columns]

# %%
## 4. Training and testing the data

# %%
X=titanic_data.drop("Survived", axis=1)
y=titanic_data["Survived"]

# %%
X
# Out:
#       Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0    22.0      1      0   7.2500     1  0  1  0  1
# 1    38.0      1      0  71.2833     0  0  0  0  0
# 2    26.0      0      0   7.9250     0  0  1  0  1
# 3    35.0      1      0  53.1000     0  0  1  0  0
# 4    35.0      0      0   8.0500     1  0  1  0  1
# ..    ...    ...    ...      ...   ... .. .. .. ..
# 885  39.0      0      5  29.1250     0  1  0  0  1
# 886  27.0      0      0  13.0000     1  0  1  1  0
# 887  19.0      0      0  30.0000     0  0  1  0  0
# 889  26.0      0      0  30.0000     1  0  0  0  0
# 890  32.0      0      0   7.7500     1  1  0  0  1
#
# [712 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logmodel = LogisticRegression()

# %%
X_train.columns = X_train.columns.astype(str)
X_test.columns = X_test.columns.astype(str)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 498 entries, 699 to 51
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     498 non-null    float64
#  1   SibSp   498 non-null    int64
#  2   Parch   498 non-null    int64
#  3   Fare    498 non-null    float64
#  4   male    498 non-null    int32
#  5   Q       498 non-null    int32
#  6   S       498 non-null    int32
#  7   2       498 non-null    int32
#  8   3       498 non-null    int32
# dtypes: float64(2), int32(5), int64(2)
# memory usage: 29.2 KB

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions_train=logmodel.predict(X_train)

# %%
predictions_test=logmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,predictions_test)
# Out:
# array([[102,  24],
#        [ 25,  63]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions_test)
# Out:
# 0.7710280373831776

# %%
from sklearn.metrics import classification_report

# %%
report_test = classification_report(y_test, predictions_test)
print(report_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       126
#            1       0.72      0.72      0.72        88
#
#     accuracy                           0.77       214
#    macro avg       0.76      0.76      0.76       214
# weighted avg       0.77      0.77      0.77       214

# %%
report_train = classification_report(y_train, predictions_train)
print(report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       298
#            1       0.79      0.69      0.74       200
#
#     accuracy                           0.80       498
#    macro avg       0.80      0.78      0.79       498
# weighted avg       0.80      0.80      0.80       498
